# %%
#importação de bibliotecas
import pandas as pd
import requests
import json

# %%
# Read the entire file as a string
with open('/content/books.json') as f:
    json_data = f.read()

# Concatenate all JSON objects into a single JSON array
json_data = '[' + ','.join(json_data.strip().split('\n')) + ']'

# Load the JSON data into a Python object
data = json.loads(json_data)

# Create a Pandas DataFrame from the data
df = pd.DataFrame(data)

# %%
# import pandas as pd
# import json

# # Initialize an empty list to store individual JSON objects
# data = []

# # Read the JSON data from the file and append each object to the list
# with open('/content/books.json') as f:
#     for line in f:
#         data.append(json.loads(line))

# # Create a Pandas DataFrame from the data
# df = pd.DataFrame(data)

# %%
# Configurando opções de exibição para desativar a notação científica
# pd.set_option('display.float_format', lambda x: '%.2f' % x)



# Resetando as opções de exibição para o padrão
#pd.reset_option('display.float_format')

# %% [markdown]
# #Trabalho Prático

# %% [markdown]
# #### 1-  Para que serve a ferramenta MogoDB Compass?
#
# r: Permite explorar os dados de forma visual.

# %% [markdown]
# #### 2-  Pela prática executada, quantos títulos foram carregados na collection livros?

# %%
df['title'].nunique()

#Serão acrescentados mais 4 itens, então 431
# Out:
# 427

# %% [markdown]
# #### 3-  Em qual das categorias de banco de dados NoSQL abaixo se enquadra o MongoDB?
#
# r: Orientado a Documentos.

# %% [markdown]
# ####4-  Pelo prompt de comando do MongoDB, como se deleta um database? Avalie a resposta pelas opções abaixo.
#
# r: Você precisa utilizar o database pelo comando use <database> e executar o comando db.dropDatabase().

# %% [markdown]
# #### 5- Pelo prompt de comando do MongoDB, o que acontece se tentarmos executar um comando insertOne inserindo dados em uma collection que não existe no MongoDB? Você pode testar: use novo `db.nova_tabela.insertOne({nome: “XPe”})`
#
# r:
# Retorna a mensagem “acknowledged: true”

# %% [markdown]
# ####6- Pela prática número 5, onde você consultou os livros com o campo pageCount menor ou igual a 100, quantos livros retornou a consulta?

# %% [markdown]
# 5) Você precisa consultar os livros com o campo pageCount menor ou igual a 100.
# Repare que esse campo é numérico. O comando abaixo vai retornar a lista de
# livros.
# Para facilitar mais ainda, você pode usar .count() ao final do comando.
#
#
#
# ```
# db.livros.find({pageCount:{$lte: 100}}) Anote esse valor.
# ```

# %%
# Consulta os livros com pageCount menor ou igual a 100
df[df['pageCount'] <= 100].shape
# Out:
# (166, 11)

# %% [markdown]
# #### 7- Pela prática número 6, onde você precisou consultar os livros com o campo isbn maior que "1933988746", quantos livros retornou a consulta?

# %% [markdown]
# 6) Agora vamos consultar os livros com o campo isbn menor ou igual a
# "1617200000". Repare que esse campo tem um conteúdo string e não
# numérico.
#
# O comando é: `db.livros.find({isbn:{$lte: "1617200000"}})`
#
# Lembre se de usar o “.count()” para facilitar o resultado.
# Mas o que realmente nos interessa é buscar os valores maiores que ($gt)
# "1933988746". Baseado no comando acima, faça os ajustes para que a
# consulta retorne apenas os maiores valores que "1933988746".

# %%
# Converter os valores da coluna 'isbn' em números inteiros
#df['isbn'] = pd.to_numeric(df['isbn'], errors='coerce')

# Consultar os livros com o campo 'isbn' menor ou igual a "1617200000"
df[df['isbn'] <= '1617200000'].shape
# Out:
# (22, 11)

# %%
df[df['isbn'] > '1933988746'].shape
# Out:
# (85, 11)

# %% [markdown]
# ### 8- Pela prática número 7, onde você precisou consultar o nome dos livros com o campo isbn menor ou igual a "1617200000", qual foi o nome do livro que tem o título começado pela letra “G”?

# %% [markdown]
# 7) Faça uma consulta na collection de livros onde o campo isbn é menor ou igual
# a "1617200000". Recupere apenas os nomes dos livros.
# Para facilitar, use algo similar ao comando
#
# ```
# db.customers.find({ }, {"name":1,
# "age":1}).
# ```

# %%
# # Converter os valores da coluna 'isbn' em números inteiros
# df['isbn'] = pd.to_numeric(df['isbn'], errors='coerce')

# Consultar os livros com o campo 'isbn' menor ou igual a "1617200000"
resultado = df[df['isbn'] <= '1617200000']
resultado.shape
# Out:
# (22, 11)

# %%
# Supondo que 'df' seja o seu DataFrame
titulo_com_g = resultado[resultado['title'].str.startswith('G', na=False)]['title'].tolist()

print(titulo_com_g)
# Out:
# ['Graphics File Formats']

# %% [markdown]
# ###9- Pela prática número 9, onde você precisou consultar os livros que tem o campo isbn menor ou igual a "10" `($lte: "10")` e depois isbn menor ou igual a "100" `($lte: "100")`, quantos livros retornaram as consultas respectivamente?

# %% [markdown]
# 8) Execute o comando abaixo para inserir mais 4 livros
#
#
# ```
# db.livros.insertMany([
# {"title" : "Saci Pererê", "isbn" : "100", "pageCount" : 0, "publishedDate":
# ISODate("2000-10-01T07:00:00Z"), "status" : "PUBLISH", "authors" : [ ], "categories"
# : [ ]},
# {"title" : "A Cuca", "isbn" : "99", "pageCount" : 0, "publishedDate": ISODate("2000-10-
# 01T07:00:00Z"), "status" : "PUBLISH", "authors" : [ ], "categories" : [ ]},
# {"title" : "Curupira", "isbn" : "98", "pageCount" : 0, "publishedDate": ISODate("2000-
# 10-01T07:00:00Z"), "status" : "PUBLISH", "authors" : [ ], "categories" : [ ]},
# {"title" : "Jeca Tatu", "isbn" : "97", "pageCount" : 0, "publishedDate": ISODate("2000-
# 10-01T07:00:00Z"), "status" : "PUBLISH", "authors" : [ ], "categories" : [ ]}
# ])
# ```

# %%
print(df.shape)

#Dados:
new_data = [
    {"title": "Saci Pererê", "isbn": "100", "pageCount": 0, "publishedDate": pd.to_datetime("2000-10-01"), "status": "PUBLISH", "authors": [], "categories": []},
    {"title": "A Cuca", "isbn": "99", "pageCount": 0, "publishedDate": pd.to_datetime("2000-10-01"), "status": "PUBLISH", "authors": [], "categories": []},
    {"title": "Curupira", "isbn": "98", "pageCount": 0, "publishedDate": pd.to_datetime("2000-10-01"), "status": "PUBLISH", "authors": [], "categories": []},
    {"title": "Jeca Tatu", "isbn": "97", "pageCount": 0, "publishedDate": pd.to_datetime("2000-10-01"), "status": "PUBLISH", "authors": [], "categories": []}
]

# Converter os dados em um DataFrame temporário
new_df = pd.DataFrame(new_data)

# Concatenar o novo DataFrame com o DataFrame existente
df = pd.concat([df, new_df], ignore_index=True)

# Mostrar o DataFrame atualizado
df.shape

print(df.shape)
# Out:
# (431, 11)
# (435, 11)

# %%
df[df['isbn'] <='10'].shape
# Out:
# (4, 11)

# %%
df[df['isbn'] <= '100'].shape
# Out:
# (5, 11)

# %% [markdown]
# ###10-.  Pela prática número 10, onde você precisou consultar os nomes dos livros que tem a chave isbn menor ou igual a "10" `($lte: "10")`, qual é o nome de um dos livros retornados na consulta?
# Grupo de escolhas da pergunta
#
# “Geographics Local“.

# %% [markdown]
# 10) Ainda utilizando o comando do passo anterior (9), a consulta retorna livros
# que tem o campo isbn menor ou igual a "10" ($lte: "10"). Quais são os 2
# primeiros livros da lista? Dica, use o comando limit() para facilitar a visualização
# do resultado.

# %%
df[df['isbn']<= '10'].head(2)
# Out:
#      _id                                              title        isbn  \
# 155  211  Comprehensive Networking Glossary and Acronym ...  013319955X
# 216  274                         Personal Videoconferencing  013268327X
#
#      pageCount                              publishedDate  \
# 155        208  {'$date': '1995-01-01T00:00:00.000-0800'}
# 216        420  {'$date': '1996-06-01T00:00:00.000-0700'}
#
#                                           thumbnailUrl  \
# 155  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 216  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
#
#                                       shortDescription  \
# 155  This glossary offers a complete collection of ...
# 216  "Personal Videoconferencing is having an enorm...
#
#                                        longDescription   status  \
# 155  This glossary offers a complete collection of ...  PUBLISH
# 216  The first book on the most powerful communicat...  PUBLISH
#
# ...

# %%
x = df.query("title == 'Comprehensive Networking Glossary and Acronym Guide'")
x
# Out:
#      _id                                              title        isbn  \
# 155  211  Comprehensive Networking Glossary and Acronym ...  013319955X
#
#      pageCount                              publishedDate  \
# 155        208  {'$date': '1995-01-01T00:00:00.000-0800'}
#
#                                           thumbnailUrl  \
# 155  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
#
#                                       shortDescription  \
# 155  This glossary offers a complete collection of ...
#
#                                        longDescription   status  \
# 155  This glossary offers a complete collection of ...  PUBLISH
#
#                  authors  categories
# 155  [Gary Scott Malkin]  [Internet]

# %% [markdown]
# ```
# No pandas, o atributo .str permite acessar uma série de métodos de string que podem ser aplicados a cada elemento de uma coluna que contenha dados do tipo string. Aqui estão algumas das principais funções disponíveis através do atributo .str:
#
# .contains(): Verifica se cada elemento da série de strings contém uma substring especificada.
#
# Exemplo:
#
# python
# Copy code
# df['coluna'].str.contains('substring')
# .startswith() e .endswith(): Verifica se cada elemento da série de strings começa ou termina com uma substring especificada.
#
# Exemplo:
#
# python
# Copy code
# df['coluna'].str.startswith('prefixo')
# df['coluna'].str.endswith('sufixo')
# .strip(), .lstrip() e .rstrip(): Remove espaços em branco à esquerda, à direita ou de ambos os lados de cada string na série.
#
# Exemplo:
#
# python
# Copy code
# df['coluna'].str.strip()
# .lower() e .upper(): Converte todas as letras em minúsculas ou maiúsculas.
#
# Exemplo:
#
# python
# Copy code
# df['coluna'].str.lower()
# .replace(): Substitui substrings dentro de cada string da série.
#
# Exemplo:
#
# python
# Copy code
# df['coluna'].str.replace('antiga', 'nova')
# .split(): Divide cada string em substrings com base em um separador especificado e retorna uma lista.
#
# Exemplo:
#
# python
# Copy code
# df['coluna'].str.split(',')
# .join(): Junta elementos de uma lista de strings usando um delimitador especificado.
#
# Exemplo:
#
# python
# Copy code
# ','.join(['string1', 'string2', 'string3'])
# Essas são apenas algumas das funções disponíveis. O atributo .str oferece uma gama de métodos para manipular dados de texto em DataFrames do Pandas.
# ```

# %% [markdown]
# ###11- Pela prática número 11, onde usamos o comando skip(), o que esse comando fez no resultado da consulta?

# %% [markdown]
# 11) O que faz o comando abaixo? Ele mostra quantos livros e porque isso?
# `db.livros.find({isbn:{$lte: "100"}}).skip(2)`

# %%
df[df['isbn']<= '100']
# Out:
#      _id                                              title        isbn  \
# 155  211  Comprehensive Networking Glossary and Acronym ...  013319955X
# 216  274                         Personal Videoconferencing  013268327X
# 276  519                               Multimedia Computing  020152029X
# 282  530               Implementing SAP R/3, Second Edition  013889213X
# 431  NaN                                        Saci Pererê         100
#
#      pageCount                              publishedDate  \
# 155        208  {'$date': '1995-01-01T00:00:00.000-0800'}
# 216        420  {'$date': '1996-06-01T00:00:00.000-0700'}
# 276          0  {'$date': '1993-09-01T00:00:00.000-0700'}
# 282          0  {'$date': '1997-09-01T00:00:00.000-0700'}
# 431          0                        2000-10-01 00:00:00
#
#                                           thumbnailUrl  \
# 155  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 216  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# ...

# %%
df[df['isbn']<= '100'].iloc[2:]  # Isso irá retornar todas as linhas a partir da terceira linha (índice 2)
# Out:
#      _id                                 title        isbn  pageCount  \
# 276  519                  Multimedia Computing  020152029X          0
# 282  530  Implementing SAP R/3, Second Edition  013889213X          0
# 431  NaN                           Saci Pererê         100          0
#
#                                  publishedDate thumbnailUrl shortDescription  \
# 276  {'$date': '1993-09-01T00:00:00.000-0700'}          NaN              NaN
# 282  {'$date': '1997-09-01T00:00:00.000-0700'}          NaN              NaN
# 431                        2000-10-01 00:00:00          NaN              NaN
#
#     longDescription   status              authors categories
# 276             NaN  PUBLISH  [Matthew E. Hodges]         []
# 282             NaN  PUBLISH                   []         []
# 431             NaN  PUBLISH                   []         []

# %% [markdown]
# ###12- Pela prática número 11, onde usamos o comando skip(), qual dos títulos de livros abaixo foi retornado pela consulta executada?
# Grupo de escolhas da pergunta

# %%
df[df['isbn']<= '100'].iloc[2:]  # Isso irá retornar todas as linhas a partir da terceira linha (índice 2)
# Out:
#      _id                                 title        isbn  pageCount  \
# 276  519                  Multimedia Computing  020152029X          0
# 282  530  Implementing SAP R/3, Second Edition  013889213X          0
# 431  NaN                           Saci Pererê         100          0
#
#                                  publishedDate thumbnailUrl shortDescription  \
# 276  {'$date': '1993-09-01T00:00:00.000-0700'}          NaN              NaN
# 282  {'$date': '1997-09-01T00:00:00.000-0700'}          NaN              NaN
# 431                        2000-10-01 00:00:00          NaN              NaN
#
#     longDescription   status              authors categories
# 276             NaN  PUBLISH  [Matthew E. Hodges]         []
# 282             NaN  PUBLISH                   []         []
# 431             NaN  PUBLISH                   []         []

# %%
x = df.query("title == 'Saci Pererê'")

# %% [markdown]
# ###13- Pela prática número 12, onde foi feita a consulta db.livros.find`({title: /Windows/}).count()`, referente aos títulos retornados, qual a palavra comum observada em todos eles?

# %%
resultados = df[df['title'].str.contains('Windows', case=False)]

resultados
# Out:
#                                       _id  \
# 111                                   163
# 189                                   246
# 190                                   247
# 195                                   252
# 315                                   644
# 316                                   645
# 328                                   659
# 364                                   723
# 400  {'$oid': '53c2ae8528d75d572c06ad9e'}
# 401  {'$oid': '53c2ae8528d75d572c06ad9f'}
# 416  {'$oid': '53c2ae8528d75d572c06adae'}
#
#                                                  title        isbn  pageCount  \
# 111     Learn Windows PowerShell in a Month of Lunches  1617290211          0
# 189                       Windows PowerShell in Action  1932394907        576
# 190       Windows PowerShell in Action, Second Edition  1935182137        700
# 195                          Windows Phone 7 in Action  1617290092          0
# ...

# %% [markdown]
# ###14- Pela prática número, 12 onde foi feita a consulta db.livros.find({title: /Windows/}).count(), quantos documentos foram retornados?

# %% [markdown]
# 12) O que faz o comando abaixo? Ele mostra quantos livros e porque isso?
# Observe o que há de comum nos títulos dos livros.
# `db.livros.find({title: /Windows/}).count()`

# %%
resultados.shape
# Out:
# (11, 11)

# %% [markdown]
# ###15- Pela prática número 13, onde foi feita uma consulta que retornou os dois maiores valores para a chave pageCount, quais foram esses valores?

# %% [markdown]
# 13) No comando find, vamos acrescentar o comando sort descendente (-1)
# para a chave pageCount.
# Utilize o comando limit = 2, pois o que quero saber é quais são os dois maiores
# valores para a chave pageCount.
#
# A dica é usar o `find({ }, {"pageCount":1, "_id":0})` para trazer apenas a chave pageCount desejada.

# %%
df.sort_values(by='pageCount', ascending=False).head(2)
# Out:
#      _id                                              title        isbn  \
# 60    70  Essential Guide to Peoplesoft Development and ...  1884777929
# 254  315                      Ten Years of UserFriendly.Org  1935182129
#
#      pageCount                              publishedDate  \
# 60        1101  {'$date': '2000-08-01T00:00:00.000-0700'}
# 254       1096  {'$date': '2008-12-01T00:00:00.000-0800'}
#
#                                           thumbnailUrl  \
# 60   https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 254  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
#
#                                       shortDescription  \
# 60                                                 NaN
# 254  This unique collector's volume includes every ...
#
#                                        longDescription   status  \
# 60   The Essential Guide to PeopleSoft Development ...  PUBLISH
# 254  For over 10 years, UserFriendly has been enter...  PUBLISH
#
# ...
